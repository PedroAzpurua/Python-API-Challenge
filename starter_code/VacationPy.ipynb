# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
#Fixed File Path
csv_file = Path("../output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         bucak  37.4592   30.5950      5.29        89          91
# 1        1       merauke  -8.4667  140.3333     27.57        78          20
# 2        2     caravelas -17.7125  -39.2481     26.04        77           1
# 3        3        albany  42.6001  -73.9662     14.09        74          15
# 4        4  beringovskiy  63.0500  179.3167     -8.06        67          55
#
#    Wind Speed Country                 Date
# 0        1.10      TR  2023-04-01 23:19:35
# 1        3.70      ID  2023-04-01 23:19:36
# 2        4.03      BR  2023-04-01 23:19:37
# 3        3.63      US  2023-04-01 23:19:20
# 4        8.81      RU  2023-04-01 23:19:38

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Trial 1
# Configure the map plot
humidity_in_city_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = .5,
    #hover_cols = ["Address", "Bank Count"]
)

# Display the map
humidity_in_city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#For my perfect Holiday I to got to travel somewhere new and WARM

filtered_city_data_df = city_data_df

filtered_city_data_df = filtered_city_data_df.loc[
    (filtered_city_data_df["Max Temp"] < 40) & (filtered_city_data_df["Max Temp"] > 20) & 
    (filtered_city_data_df["Lat"] > 0) &
    (filtered_city_data_df["Cloudiness"] < 10)&
    (filtered_city_data_df["Wind Speed"] < 6)
    ]


# Drop any rows with null values
filtered_city_data_df = filtered_city_data_df.dropna()

# Display sample data
filtered_city_data_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 103      103      rosarito  32.3333 -117.0333     20.69        64           0
# 128      128     taranagar  28.6709   75.0351     21.10        62           6
# 153      153    sao filipe  14.8961  -24.4956     26.63        50           0
# 179      179  saint george  37.1041 -113.5841     20.24        24           0
# 204      204     taoudenni  22.6783   -3.9836     28.57         7           0
# 215      215       umarkot  25.3616   69.7362     23.15        61           0
# 251      251         basco  20.4487  121.9702     25.15        81           8
# 264      264      umm lajj  25.0213   37.2685     20.79        47           0
# 267      267           sur  22.5667   59.5289     26.03        61           4
# 269      269        kibala   9.1104   18.3463     30.40        27           8
# 272      272         lamar  33.6668  -95.5836     21.95        29           0
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filtered_city_data_df

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 103      103      rosarito  32.3333 -117.0333     20.69        64           0
# 128      128     taranagar  28.6709   75.0351     21.10        62           6
# 153      153    sao filipe  14.8961  -24.4956     26.63        50           0
# 179      179  saint george  37.1041 -113.5841     20.24        24           0
# 204      204     taoudenni  22.6783   -3.9836     28.57         7           0
# 215      215       umarkot  25.3616   69.7362     23.15        61           0
# 251      251         basco  20.4487  121.9702     25.15        81           8
# 264      264      umm lajj  25.0213   37.2685     20.79        47           0
# 267      267           sur  22.5667   59.5289     26.03        61           4
# 269      269        kibala   9.1104   18.3463     30.40        27           8
# 272      272         lamar  33.6668  -95.5836     21.95        29           0
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 1

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params = {
        "apiKey": geoapify_key,
        "limit": limit,
        "filter": f"circle:{lng},{lat},{radius}",
        "bias": f"proximity:{lng},{lat}",
        "categories": "accommodation.hotel"    
    }
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    # params["filter"] = # YOUR CODE HERE
    # params["bias"] = # YOUR CODE HERE
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    print(name_address)
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Max Temp",
    scale = 1,
    color = "City",
    alpha = .5,
    hover_cols = ["Hotel Name","Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country)

# %%
#Takigng it one step further and removing all line items where hotel is not found

hotel_available_df = hotel_df
hotel_available_df = hotel_available_df.loc[hotel_available_df["Hotel Name"] != "No hotel found"]
hotel_available_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 103      103      rosarito  32.3333 -117.0333     20.69        64           0
# 153      153    sao filipe  14.8961  -24.4956     26.63        50           0
# 179      179  saint george  37.1041 -113.5841     20.24        24           0
# 251      251         basco  20.4487  121.9702     25.15        81           8
# 267      267           sur  22.5667   59.5289     26.03        61           4
# 269      269        kibala   9.1104   18.3463     30.40        27           8
# 272      272         lamar  33.6668  -95.5836     21.95        29           0
# 319      319     boa vista   2.8197  -60.6733     29.99        51           0
# 330      330       buckeye  33.3703 -112.5838     27.61        12           0
# 370      370   trincomalee   8.5711   81.2335     25.81        86           3
# 381      381         praya  14.9215  -23.5087     24.30        25           0
# ...

# %%
#Show me the same map as above except with only the cities where we have found a hotel
hotel_map2 = hotel_available_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Max Temp",
    scale = 1,
    color = "City",
    alpha = .5,
    hover_cols = ["Hotel Name","Country"]
)

# Display the map
hotel_map2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country)
